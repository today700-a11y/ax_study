# %%
user_info = {"이름": "Sparta", "나이": 20}
user_info["나이"] = 21
print(user_info["나이"])

user_info.get("phone", "010-0000-0000")
# Out:
# 21
# '010-0000-0000'

# %%
raw_emails = ["a@sparta.com", "b@sparta.com", "a@sparta.com"]
raw_emails = set(raw_emails)

refined_emails = list(raw_emails)
refined_emails
# Out:
# ['b@sparta.com', 'a@sparta.com']

# %%
raw_emails = ["a@sparta.com", "b@sparta.com", "a@sparta.com"]
refined_emails = list(set(raw_emails))

refined_emails
# Out:
# ['b@sparta.com', 'a@sparta.com']

# %%
menu = {"coffe": 4000, "tea": 4500}
menu.keys(), menu.values()
# Out:
# (dict_keys(['coffe', 'tea']), dict_values([4000, 4500]))

# %%
set_a = {1, 2, 3}
set_b = {3, 4, 5}
set_a & set_b
# Out:
# {3}

# %%
print(set_a | set_b)
print(set_a - set_b)
# Out:
# {1, 2, 3, 4, 5}
# {1, 2}
