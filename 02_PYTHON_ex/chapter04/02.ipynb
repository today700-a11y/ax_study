# %%
for i in range(1, 5):
    print(f"{i} 번째 고객님입니다.")

# %%
while True:
    for i in range(80, 101, 5):
        print("현재 배터리: ", f"{i}")
    if i ==100:
        break
# Out:
# 현재 배터리:  80
# 현재 배터리:  85
# 현재 배터리:  90
# 현재 배터리:  95
# 현재 배터리:  100
