# %%
message = "내 이름은 %s이고, 나이는 %d입니다."

message % ("노예권", 20)
# Out:
# '내 이름은 노예권이고, 나이는 20입니다.'

# %%
name = "노예권"
age = 20

message = "내 이름은 {name}이고, 나이는 {age}살입니다. "
print(message.format(name=name, age=age))
# Out:
# 내 이름은 노예권이고, 나이는 20살입니다.

# %%
result = 10 + 3.14
print(int(result))
# Out:
# 13

# %%
user_input = "20세"
if user_input.isdigit():
    age = int(user_input)
    print("정수 전환 성공")
else:
    print("숫자만 입력해 주세요!")
# Out:
# 숫자만 입력해 주세요!
