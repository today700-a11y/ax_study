# %%
message = "상품: %s| 가격:%d"
message2 = message % ("Americano", 4500)
message2
# Out:
# '상품: Americano| 가격:4500'

# %%
message
# Out:
# '상품: %s| 가격:%d'

# %%
"상품: %s| 가격:%d" % ("TEST", 1)
# Out:
# '상품: TEST| 가격:1'

# %%
"상품: %s| 가격:%d" %("Americano", 4500)
# Out:
# '상품: Americano| 가격:4500'

# %%
price = 15000
print(f"금액: {price:>8,}")
# Out:
# 금액:   15,000
