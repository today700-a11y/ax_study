# %% [markdown]
# # 2장 2강: 기본 자료형과 형변환

# %% [markdown]
# ### 0. 주석(comment)

# %% [markdown]
# 코드 상에 설명을 추가할 때 사용, 인터프리터가 해석 하지 않는다.
# - \# : 한줄 주석
# - """ ... """ : 여러줄 주석
#
#
# 코드 실행 배제: 인터프리터가 해석을 하지 않으므로 코드 실행을 배제할 수 있음

# %%
# 코드 설명...
"""
한줄
두줄
세줄
"""
# Out:
# '\n한줄\n두줄\n세줄\n'

# %% [markdown]
# ### 1. 파이썬의 기본 자료형(Primitive Data Types)

# %% [markdown]
# - 자료: 연산에 필요한 값(데이터)
# - 자료형: 값의 유형(데이터의 종류)
#
# #### 자료형
# - 숫자형: 정수형(int, 10, 20, ...), 실수형(float, 10.123, ...)
# - 논리형: 참(True), 거짓(False)
# - 문자형: 문자, 문장, '', "" 감싸서 선언(한줄), """ """ 감싸면 여러줄 문장
# - 값 없음: None

# %%
money = None

# %%
message = """안녕하세요.
반갑습니다.
"""
type(message)
# Out:
# str

# %% [markdown]
# ### 2. 명시적 형변환(Explicit Type Conversion)

# %% [markdown]
# 연산은 같은 자료형끼리 가능
#
# 형변환 함수
# - int(..) : 정수로 변환
# - float(..) : 실수로 변환
# - bool(...) : True, False로 변환
# - str(..) : 문자형으로 변환

# %%
num = "100"
type(num)
# Out:
# str

# %%
int(num) + 200
# Out:
# 300

# %%
"현재 시간은 " + str(10) + "시"
# Out:
# '현재 시간은 10시'

# %% [markdown]
# ### 3. 묵시적 형병환(Implicit Type Conversion)

# %%
num1 = 100
num2 = 3.123

type(num1), type(num2)
# Out:
# (int, float)

# %%
num3 = num1 + num2 # num1 이 int -> float 자동 형변환(묵시적 형변환)
# num3 = num1 + int(num2)

num3, type(num3)
# Out:
# (103.123, float)

# %% [markdown]
# ### 4. 형변환 시 주의해야 할 예외와 에러(ValueError)

# %%
time = "10시"
if time.isdigit():
    int(time) + 1

# %% [markdown]
# ### 5. 거짓으로 인식하는 값
# 0, "", [], None

# %%
message = "1"
if message:
        print("있음")
# Out:
# 있음

# %%
type(message)
# Out:
# str

# %%
result = bool(message)
result, type(result)
# Out:
# (True, bool)
