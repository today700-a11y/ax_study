# %%
x = 5000
x
# Out:
# 5000

# %%
id(x)
# Out:
# 1849723510864

# %%
y = x
y
# Out:
# 5000

# %%
id(y)
# Out:
# 1849723510864

# %%
x = 500
id(x)
# Out:
# 1849723512944

# %%
x = 600
id(x)
# Out:
# 1849723513872

# %%
id(x)
# Out:
# 1849723513872

# %%
a = 10
id(a)
# Out:
# 140712933594312

# %%
a=20
id(a)
# Out:
# 140712933594632

# %%
a = 10
id(a)
# Out:
# 140712933594312

# %%
number_of_student = 100

# %%
type(number_of_student)
# Out:
# int

# %%
pi = 3.14
type(pi)
# Out:
# float

# %%
result = True
type(result)
# Out:
# bool

# %%
pi = "원주율"
type(pi)
# Out:
# str
